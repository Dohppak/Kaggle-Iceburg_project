# %%
import gc
import time
import numpy as np
import pandas as pd
from sklearn.cross_validation import train_test_split
import warnings
warnings.filterwarnings('ignore')
import os
path = '../../../DEVELOPMENT/Fraud Detection/input/'

dtypes = {
        'ip'            : 'uint32',
        'app'           : 'uint16',
        'device'        : 'uint16',
        'os'            : 'uint16',
        'channel'       : 'uint16',
        'is_attributed' : 'uint8',
        'click_id'      : 'uint32'
        }

# %%
train_sample = pd.read_csv(path+'train_sample.csv', dtype=dtypes)

# %%
train_sample.head()
# Out:
#        ip  app  device  os  channel           click_time attributed_time  \
# 0   87540   12       1  13      497  2017-11-07 09:30:38             NaN
# 1  105560   25       1  17      259  2017-11-07 13:40:27             NaN
# 2  101424   12       1  19      212  2017-11-07 18:05:24             NaN
# 3   94584   13       1  13      477  2017-11-07 04:58:08             NaN
# 4   68413   12       1   1      178  2017-11-09 09:00:09             NaN
#
#    is_attributed
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0

# %%
def prep_data(d):
    d['hour'] = pd.to_datetime(d.click_time).dt.hour.astype('uint8')
    d['day'] = pd.to_datetime(d.click_time).dt.day.astype('uint8')
    d['wday']  = pd.to_datetime(d.click_time).dt.dayofweek.astype('uint8')
    
    print('grouping by ip-day-hour combination')
    gp = d[['ip','day','hour','channel']].groupby(by=['ip','day','hour'])[['channel']].count().reset_index().rename(index=str, columns={'channel': 'ip-day-hour'})
    d = d.merge(gp, on=['ip','day','hour'], how='left')
    del gp; gc.collect()
    
    print('group by ip-app combination')
    gp = d[['ip','app', 'channel']].groupby(by=['ip', 'app'])[['channel']].count().reset_index().rename(index=str, columns={'channel': 'ip_app_count'})
    d = d.merge(gp, on=['ip','app'], how='left')
    del gp; gc.collect()
    
    print('group by ip-app-os combination')
    gp = d[['ip','app', 'os', 'channel']].groupby(by=['ip', 'app', 'os'])[['channel']].count().reset_index().rename(index=str, columns={'channel': 'ip_app_os_count'})
    d = d.merge(gp, on=['ip','app', 'os'], how='left')
    del gp; gc.collect()
    
    print("vars and data type")
    d['ip-day-hour'] = d['ip-day-hour'].astype('uint16')
    d['ip_app_count'] = d['ip_app_count'].astype('uint16')
    d['ip_app_os_count'] = d['ip_app_os_count'].astype('uint16')
    
    print("label encoding....")
    from sklearn.preprocessing import LabelEncoder
    d[['app','device','os', 'channel', 'hour', 'day', 'wday']].apply(LabelEncoder().fit_transform)
    print('dropping')
    d.drop(['click_time', 'ip'], 1, inplace=True)
    
    return d

# %%
train_df1 = prep_data(train_sample)
# Out:
# grouping by ip-day-hour combination
# group by ip-app combination
# group by ip-app-os combination
# vars and data type
# label encoding....
# dropping

# %%
train_df1.head(30)
# Out:
#     app  device  os  channel attributed_time  is_attributed  hour  day  wday  \
# 0    12       1  13      497             NaN              0     9    7     1
# 1    25       1  17      259             NaN              0    13    7     1
# 2    12       1  19      212             NaN              0    18    7     1
# 3    13       1  13      477             NaN              0     4    7     1
# 4    12       1   1      178             NaN              0     9    9     3
# 5     3       1  17      115             NaN              0     1    9     3
# 6     1       1  17      135             NaN              0     1    9     3
# 7     9       1  25      442             NaN              0    10    7     1
# 8     2       2  22      364             NaN              0     9    8     2
# 9     3       1  19      135             NaN              0    12    8     2
# 10    3       1  22      489             NaN              0     8    8     2
# 11    3       1  13      489             NaN              0     5    7     1
# 12    3       1  22      205             NaN              0    10    9     3
# 13    6       1  20      125             NaN              0    14    8     2
# 14    2       1  13      205             NaN              0     0    7     1
# 15   25       2  19      259             NaN              0    23    8     2
# 16    2       1   2      477             NaN              0     7    9     3
# 17    3       1  20      280             NaN              0     3    9     3
# 18   20       2  90      259             NaN              0    23    6     0
# 19   14       1  13      349             NaN              0    20    6     0
# 20   12       1  19      265             NaN              0     9    9     3
# 21   64       1  25      459             NaN              0    17    8     2
# 22    9       1  10      215             NaN              0     2    8     2
# 23    7       1  19      101             NaN              0    10    7     1
# 24    3       1  18      280             NaN              0     1    7     1
# 25   64       1  13      459             NaN              0     3    7     1
# 26    3       1  13      115             NaN              0    16    7     1
# 27    1       1  13      115             NaN              0    17    7     1
# 28   12       1  40      122             NaN              0     6    7     1
# 29   12       1  13      497             NaN              0    10    7     1
#
#     ip-day-hour  ip_app_count  ip_app_os_count
# 0             1             3                2
# 1             4             4                1
# 2             1             1                1
# 3             1             1                1
# 4             1             2                1
# 5             1             1                1
# 6             1             1                1
# 7             1             2                1
# 8             1             5                1
# 9             1             1                1
# 10            1             9                1
# 11            2             2                1
# 12            1             3                1
# 13            5             3                1
# 14            1            30                5
# 15            1             1                1
# 16            3            61                1
# 17            2             6                1
# 18            1             1                1
# 19            1             2                2
# 20            2             1                1
# 21            1             1                1
# 22            1             2                1
# 23            1             1                1
# 24            1             2                1
# 25            1             1                1
# 26            1             1                1
# 27            1             2                1
# 28            1             1                1
# 29            1             1                1

# %%
from sklearn.model_selection import train_test_split

predictors = train_df1.drop(['attributed_time', 'is_attributed'], axis=1)
target = train_df1["is_attributed"]

x_train, x_test, y_train, test = train_test_split(predictors, target, test_size = 0.1, random_state = 1)

# %%
x_train.head(30)
# Out:
#        app  device  os  channel  hour  day  wday  ip-day-hour  ip_app_count  \
# 61010    6       1  30      459    11    7     1            1             1
# 77750    9       1  14      466    15    9     3            1             1
# 91401   26       1  16      121    15    9     3            1             1
# 42871    2       1  13      219    16    7     1            2             2
# 16411   18       1  19      121     2    9     3            1             6
# 87482   15       1   6      265    22    8     2            1             1
# 61007   18       1  22      107    13    9     3            1             1
# 95105   18       2  27      449    13    9     3            6             9
# 94181    1       1  13       17    14    8     2            1             1
# 10346    9       1  19      134     1    8     2            1             1
# 81803    9       2  17      258    16    6     0            1             2
# 44501    8       2  19      259     4    7     1            2             8
# 89961   12       1  19      178     7    8     2            1             1
# 76548   18       1  13      121     2    9     3            1             2
# 74829   18       1  13      134    11    9     3           24            55
# 74808    9       2  13      234    15    9     3            1             1
# 99170    3       1   8      280     9    8     2            1             4
# 48597   21       1  35      232    12    9     3            2             1
# 36193   11       1  19      481     6    9     3            1             1
# 44853    3       1  13      402     1    8     2            1             5
# 72706   14       1  11      134    14    8     2            1             1
# 25180    9       1  37      334     2    9     3            1             1
# 53658    3       1  13      280    11    8     2            1             1
# 28679   14       1  12      134     7    9     3            2             2
# 64872    3       1   8      115     2    7     1            1             1
# 11729   18       1  20      107     3    8     2            1             2
# 75817    3       1  25      280     9    8     2            2            19
# 98481   14       1  13      460    14    9     3            1             2
# 85521   17       1  13      280    23    6     0            1             1
# 18248    3       1  17      452     3    8     2            1             1
#
#        ip_app_os_count
# 61010                1
# 77750                1
# 91401                1
# 42871                2
# 16411                1
# 87482                1
# 61007                1
# 95105                1
# 94181                1
# 10346                1
# 81803                1
# 44501                2
# 89961                1
# 76548                1
# 74829               10
# 74808                1
# 99170                1
# 48597                1
# 36193                1
# 44853                2
# 72706                1
# 25180                1
# 53658                1
# 28679                1
# 64872                1
# 11729                1
# 75817                1
# 98481                1
# 85521                1
# 18248                1

# %%
x_train, x_test, y_train, test = train_test_split(predictors, target, test_size = 0.1, random_state = 1)

# %%
print("훈련 세트 정확도: {:.3f}".format(gbk.score(x_train, y_train)))
print("테스트 세트 정확도: {:.3f}".format(gbk.score(x_test, test)))
# Out:
# 훈련 세트 정확도: 0.998
# 테스트 세트 정확도: 0.998

# %%
print("훈련 세트 정확도: {:.3f}".format(gbk.score(x_train, y_train)))
print("테스트 세트 정확도: {:.3f}".format(gbk.score(x_test, test)))
# Out:
# 훈련 세트 정확도: 0.998
# 테스트 세트 정확도: 0.998

# %%
plot_feature_importances_cancer(gbk)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-e908f6e20eda> in <module>()
# ----> 1 plot_feature_importances_cancer(gbk)
#
# NameError: name 'plot_feature_importances_cancer' is not defined

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score,confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score

# %%
gbk_roc = roc_auc_score(test, gbk.predict_proba(x_test)[:,1])
print('ROC : ',gbk_roc)
# Out:
# ROC :  0.948601348319

# %%
predictions = gbk.predict_proba(x_test)
predictions
# Out:
# array([[  9.99545556e-01,   4.54444107e-04],
#        [  9.99672115e-01,   3.27885149e-04],
#        [  9.99523163e-01,   4.76836667e-04],
#        ...,
#        [  9.99706818e-01,   2.93181506e-04],
#        [  9.99523163e-01,   4.76836667e-04],
#        [  9.99655956e-01,   3.44043711e-04]])

# %%
test = pd.read_csv(path+'test.csv', dtype=dtypes)
test.tail()
# Out:
#           click_id      ip  app  device  os  channel           click_time
# 18790464  18790464   99442    9       1  13      127  2017-11-10 15:00:00
# 18790465  18790465   88046   23       1  37      153  2017-11-10 15:00:00
# 18790466  18790467   81398   18       1  17      265  2017-11-10 15:00:00
# 18790467  18790466  123236   27       1  13      122  2017-11-10 15:00:00
# 18790468  18790468   73516   12       2  27      265  2017-11-10 15:00:00

# %%
test_df = prep_data(test)
# Out:
# grouping by ip-day-hour combination
# group by ip-app combination
# group by ip-app-os combination
# vars and data type
# label encoding....
# dropping

# %%
test_df.head()
# Out:
#    click_id  app  device  os  channel  hour  day  wday  ip-day-hour  \
# 0         0    9       1   3      107     4   10     4           34
# 1         1    9       1   3      466     4   10     4          403
# 2         2   21       1  19      128     4   10     4          229
# 3         3   15       1  13      111     4   10     4          239
# 4         4   12       1  13      328     4   10     4           60
#
#    ip_app_count  ip_app_os_count
# 0            28                1
# 1           289                5
# 2           312               24
# 3            42               23
# 4            24                7

# %%
test_df = test_df.drop('click_id', axis = 1)

# %%
predictions = gbk.predict_proba(test_df)

# %%
sub = pd.DataFrame()
sub['click_id'] = test['click_id'].astype('int')
test.drop(['click_id'], axis=1, inplace=True)
gc.collect()
# Out:
# 53

# %%
sub2 = pd.DataFrame()
sub['click_id'] = sub['click_id'].astype('int')
gc.collect()
# Out:
# 0

# %%
def convert_preds(raw_preds):
    preds = []
    for p in raw_preds:
        preds.append(1 - p[0])
    return preds

# %%
val_preds = convert_preds(predictions)

# %%
sub['is_attributed'] = val_preds
sub.head()
# Out:
#    click_id  is_attributed
# 0         0       0.000293
# 1         1       0.000328
# 2         2       0.000108
# 3         3       0.002578
# 4         4       0.000328

# %%
max(val_preds)
# Out:
# 1.0

# %%
sub.to_csv('GBK.csv', float_format='%.8f', index=False)
